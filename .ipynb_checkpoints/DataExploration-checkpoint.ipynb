# %%
# !pip install requests
# Out:
# Collecting requests
#   Downloading requests-2.24.0-py2.py3-none-any.whl (61 kB)
# Collecting chardet<4,>=3.0.2
#   Downloading chardet-3.0.4-py2.py3-none-any.whl (133 kB)
# Collecting urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1
#   Downloading urllib3-1.25.9-py2.py3-none-any.whl (126 kB)
# Collecting certifi>=2017.4.17
#   Downloading certifi-2020.6.20-py2.py3-none-any.whl (156 kB)
# Collecting idna<3,>=2.5
#   Downloading idna-2.9-py2.py3-none-any.whl (58 kB)
# Installing collected packages: chardet, urllib3, certifi, idna, requests
# Successfully installed certifi-2020.6.20 chardet-3.0.4 idna-2.9 requests-2.24.0 urllib3-1.25.9

# %%
import requests

# %%
import base64

# %%
import datetime

# %%
client_id = 'ed343e6c5eeb411a9b8e97398d6fa29b'
client_secret = 'd0480725f56041359cd745fd524ea790'

# %%
class SpotifyAPI(object):
    access_token = None
    access_token_expires = datetime.datetime.now()
    access_token_did_expire = True
    client_id = None
    client_secret = None
    token_url = 'https://accounts.spotify.com/api/token'
    
    
    def __init__(self,client_id, client_secret, *args, **kwargs):
        super().__init__(*args,**kwargs)
        self.client_id = client_id
        self.client_secret = client_secret
    
    def get_client_credentials(self):
        self.client_id = client_id
        self.client_secret = client_secret
        if client_secret == None or client_id == None:
            raise Exception('You must set client_id and client_secrets')
        client_creds = f'{client_id}:{client_secret}'
        client_creds_b64 = base64.b64encode(client_creds.encode())
        return client_creds_b64.decode()
    
    def get_token_header(self):
        client_creds_b64 = self.get_client_credentials()
        return {
            'Authorization': f'Basic {client_creds_b64}'
        }
    
    def get_token_data(self):
        return {
            'grant_type':'client_credentials'
        }
    
    def perform_auth(self):
        token_url = self.token_url
        token_data = self.get_token_data()
        token_headers = self.get_token_header()
        r = requests.post(token_url,data=token_data,headers=token_headers)
        
        if r.status_code not in range(200,299):
            raise Exception('Could not authenticate client.')
        data = r.json()
        now = datetime.datetime.now()
        expires_in = data['expires_in']
        expires = now + datetime.timedelta(seconds=expires_in)
        self.access_token = data['access_token']
        self.access_token_expires = expires
        self.access_token_did_expire = expires < now
        return True
    
    def get_access_token(self):
        token = self.access_token
        expires = self.access_token_expires
        now = datetime.datetime.now()
        if expires < now:
            self.perform_auth()
            return self.get_access_token()
        elif token == None:
            self.perform_auth()
            return self.get_access_token()
        return token
    
    def get_album(self, _id):
        return self.get_resource(_id, resource_type='albums')
    
    def get_artist(self, _id):
        return self.get_resource(_id, resource_type='artists')
    
    def get_resource_header(self):
        access_token = self.get_access_token()
        headers = {
            'Authorization': f'Bearer {access_token}'
        }
        return headers
    
    def get_resource(self, lookup_id, resource_type='albums', version='v1'):
        endpoint = f'https://api.spotify.com{version}/{resource_type}/{lookup_id}'
        headers = self.get_resource_header()
        r = requests.get(endpoint, headers=headers)
        if r.status_code not in range(200,299):
            return {}
        return r.json()
    
    def search(self, query, search_type='artist' ):
        access_token = self.get_access_token()
        headers = {
            'Authorization': f'Bearer {access_token}'
        }
        endpoint = 'https://api.spotify.com/v1/search'
        data = urlencode({'q': 'Time', 'type': search_type.lower()})
        lookup_url = f'{endpoint}?{data}'
        r = requests.get(lookup_url, headers=headers)
        if r.status_code not in range(200, 299):
            return {}
        return r.json()

# %%
client_creds = f'{client_id}:{client_secret}'
type(client_creds)
# Out:
# str

# %%
client_creds_b64 = base64.b64encode(client_creds.encode())
type(client_creds_b64)
# Out:
# bytes

# %%
token_url = 'https://accounts.spotify.com/api/token'
method = 'POST'
token_data = {
    'grant_type':'client_credentials'
}
token_headers = {
    'Authorization': f'Basic {client_creds_b64.decode()}'
}

# %%
r = requests.post(token_url,data=token_data,headers=token_headers)
print(r.json())
# Out:
# {'access_token': 'BQDBkmNjKbjrz_DjNZg1Rcor39oEG6ddKkdaOWfYG4uZD0k1DqYYVHnxW1n7ggnSpmPNdT9imv_w0mgB8A8', 'token_type': 'Bearer', 'expires_in': 3600, 'scope': ''}

# %%
valid_request = r.status_code in range(200,299)
if valid_request:
    token_response_data = r.json()
    now = datetime.datetime.now()
    access_token = token_response_data['access_token']
    expires_in = token_response_data['expires_in']
    expires = now + datetime.timedelta(seconds=expires_in)
    did_expire = expires < now

# %% [markdown]
# ## Let's explore, now that we have a Spotify class

# %%
from urllib.parse import urlencode

# %%
spotify = SpotifyAPI(client_id, client_secret)

# %%
spotify.perform_auth()
# Out:
# True

# %%
spotify.access_token
# Out:
# 'BQD3Uv2vJg893S8oaqkcQNMkBCGzQKQ36Y1CLZiXuny_0naprYkdInv5Yo1agLUM0KZb97WrHRt5Pp82ry4'

# %%
#spotify search
headers = {
    'Authorization': f'Bearer {spotify.access_token}'
}
endpoint = 'https://api.spotify.com/v1/search'
data = urlencode({'q': 'Time', 'type': 'track'})
lookup_url = f'{endpoint}?{data}'
r = requests.get(lookup_url, headers=headers)
print(r.status_code)
# Out:
# 200

# %%
spotify.search('Dr. Dog')
# Out:
# {'artists': {'href': 'https://api.spotify.com/v1/search?query=Time&type=artist&offset=0&limit=20',
#   'items': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/6dC0rIJNLSFZwqckLgXJ8p'},
#     'followers': {'href': None, 'total': 293970},
#     'genres': ['dance pop',
#      'indie pop rap',
#      'pop',
#      'pop rap',
#      'pop rock',
#      'post-teen pop',
#      'tropical house'],
#     'href': 'https://api.spotify.com/v1/artists/6dC0rIJNLSFZwqckLgXJ8p',
#     'id': '6dC0rIJNLSFZwqckLgXJ8p',
#     'images': [{'height': 1000,
#       'url': 'https://i.scdn.co/image/b81e5fa38ce9af63d09a5e93f8524c42f6d02ea4',
#       'width': 1000},
#      {'height': 640,
#       'url': 'https://i.scdn.co/image/741dcbf70f4fc157a818fa9c73a39e023f8a446b',
#       'width': 640},
#      {'height': 200,
#       'url': 'https://i.scdn.co/image/dc6f5e949d9559aa8091a405bda421c11ad8177e',
#       'width': 200},
#      {'height': 64,
#       'url': 'https://i.scdn.co/image/6c709d0a985278765ea0f52028a33dd57bca066f',
#       'width': 64}],
#     'name': 'Timeflies',
#     'popularity': 64,
#     'type': 'artist',
#     'uri': 'spotify:artist:6dC0rIJNLSFZwqckLgXJ8p'},
#    {'external_urls': {'spotify': 'https://open.spotify.com/artist/6zrgIu0skCCFS7Ke9xOj1r'},
#     'followers': {'href': None, 'total': 87524},
#     'genres': ['cyberpunk', 'synthwave'],
#     'href': 'https://api.spotify.com/v1/artists/6zrgIu0skCCFS7Ke9xOj1r',
#     'id': '6zrgIu0skCCFS7Ke9xOj1r',
#     'images': [{'height': 640,
#       'url': 'https://i.scdn.co/image/b6fcac7135efbae0fbf5b4916a47b1cd5e7262b8',
#       'width': 640},
#      {'height': 320,
#       'url': 'https://i.scdn.co/image/c3a8f199743b70676c28600a18b2ae3813c2f11e',
#       'width': 320},
#      {'height': 160,
#       'url': 'https://i.scdn.co/image/545496369e8b96135ae4d0a62db71823f516d6f9',
#       'width': 160}],
#     'name': 'Timecop1983',
#     'popularity': 55,
#     'type': 'artist',
#     'uri': 'spotify:artist:6zrgIu0skCCFS7Ke9xOj1r'},
#    {'external_urls': {'spotify': 'https://open.spotify.com/artist/46gyXjRIvN1NL1eCB8GBxo'},
#     'followers': {'href': None, 'total': 2298192},
#     'genres': ['modern rock', 'pop punk', 'post-teen pop'],
#     'href': 'https://api.spotify.com/v1/artists/46gyXjRIvN1NL1eCB8GBxo',
#     'id': '46gyXjRIvN1NL1eCB8GBxo',
#     'images': [{'height': 640,
#       'url': 'https://i.scdn.co/image/12ca3775837790e8c7da4a7d5cd34f9381cd39c1',
#       'width': 640},
#      {'height': 320,
#       'url': 'https://i.scdn.co/image/ef7de71bc9755534900ab4b8c35db3a1a3e2a557',
#       'width': 320},
#      {'height': 160,
#       'url': 'https://i.scdn.co/image/37884af22969d472462d73e59fb3f56074c87791',
#       'width': 160}],
#     'name': 'All Time Low',
#     'popularity': 75,
#     'type': 'artist',
#     'uri': 'spotify:artist:46gyXjRIvN1NL1eCB8GBxo'},
#    {'external_urls': {'spotify': 'https://open.spotify.com/artist/5XMVfR85CUqujqUkN9c9VQ'},
#     'followers': {'href': None, 'total': 19506},
#     'genres': ['djent', 'german metalcore', 'metalcore'],
#     'href': 'https://api.spotify.com/v1/artists/5XMVfR85CUqujqUkN9c9VQ',
#     'id': '5XMVfR85CUqujqUkN9c9VQ',
#     'images': [{'height': 640,
#       'url': 'https://i.scdn.co/image/e7f01acca6ff043bd5b8efd6a3ac92c1d7df1970',
#       'width': 640},
#      {'height': 320,
#       'url': 'https://i.scdn.co/image/bbbf7d7ea0a8cbe46b0b8b6184cba76ae195920c',
#       'width': 320},
#      {'height': 160,
#       'url': 'https://i.scdn.co/image/e2e9a3865d1131770762c253773282e7a3ab661b',
#       'width': 160}],
#     'name': 'Time, The Valuator',
#     'popularity': 42,
#     'type': 'artist',
#     'uri': 'spotify:artist:5XMVfR85CUqujqUkN9c9VQ'},
#    {'external_urls': {'spotify': 'https://open.spotify.com/artist/1EgGVV9cmmlLEsFlunjmvv'},
#     'followers': {'href': None, 'total': 266266},
#     'genres': ['electro',
#      'funk',
#      'funk rock',
#      'minneapolis sound',
#      'new jack swing',
#      'post-disco',
#      'quiet storm',
#      'synth funk',
#      'urban contemporary'],
#     'href': 'https://api.spotify.com/v1/artists/1EgGVV9cmmlLEsFlunjmvv',
#     'id': '1EgGVV9cmmlLEsFlunjmvv',
#     'images': [{'height': 640,
#       'url': 'https://i.scdn.co/image/ab67616d0000b273c093f4dd308ad9c41e20eee8',
#       'width': 640},
#      {'height': 300,
#       'url': 'https://i.scdn.co/image/ab67616d00001e02c093f4dd308ad9c41e20eee8',
#       'width': 300},
#      {'height': 64,
#       'url': 'https://i.scdn.co/image/ab67616d00004851c093f4dd308ad9c41e20eee8',
#       'width': 64}],
#     'name': 'The Time',
#     'popularity': 48,
#     'type': 'artist',
#     'uri': 'spotify:artist:1EgGVV9cmmlLEsFlunjmvv'},
#    {'external_urls': {'spotify': 'https://open.spotify.com/artist/0GWCNkPi54upO9WLlwjAHd'},
#     'followers': {'href': None, 'total': 1811601},
#     'genres': ['boy band', 'dance pop', 'pop', 'post-teen pop', 'viral pop'],
#     'href': 'https://api.spotify.com/v1/artists/0GWCNkPi54upO9WLlwjAHd',
#     'id': '0GWCNkPi54upO9WLlwjAHd',
#     'images': [{'height': 640,
#       'url': 'https://i.scdn.co/image/1c72dce35a2e8d340dea9f567ffa137180f45769',
#       'width': 640},
#      {'height': 320,
#       'url': 'https://i.scdn.co/image/28802e61ed9e1807e3e4d493aa256cad6e287d04',
#       'width': 320},
#      {'height': 160,
#       'url': 'https://i.scdn.co/image/a2eff131087b60a68579217403948fc74e4a67ca',
#       'width': 160}],
#     'name': 'Big Time Rush',
#     'popularity': 69,
#     'type': 'artist',
#     'uri': 'spotify:artist:0GWCNkPi54upO9WLlwjAHd'},
#    {'external_urls': {'spotify': 'https://open.spotify.com/artist/0CfztphU9FWmAhGocFrrYC'},
#     'followers': {'href': None, 'total': 49125},
#     'genres': ['boston metal', 'melodic metalcore', 'metalcore'],
#     'href': 'https://api.spotify.com/v1/artists/0CfztphU9FWmAhGocFrrYC',
#     'id': '0CfztphU9FWmAhGocFrrYC',
#     'images': [{'height': 630,
#       'url': 'https://i.scdn.co/image/482ee5caaf5b22405b3b75cb28e54d1b980c01b8',
#       'width': 630},
#      {'height': 200,
#       'url': 'https://i.scdn.co/image/403542e3e6d58f0efb33d3791ffce531c5544638',
#       'width': 200},
#      {'height': 64,
#       'url': 'https://i.scdn.co/image/0dc839cca3e6e8d17ee6f78313a68eed9a98c492',
#       'width': 64}],
#     'name': 'Times Of Grace',
#     'popularity': 40,
#     'type': 'artist',
#     'uri': 'spotify:artist:0CfztphU9FWmAhGocFrrYC'},
#    {'external_urls': {'spotify': 'https://open.spotify.com/artist/2tZbAzQxbp2fvMbVR9glOT'},
#     'followers': {'href': None, 'total': 2887},
#     'genres': ['sleep'],
#     'href': 'https://api.spotify.com/v1/artists/2tZbAzQxbp2fvMbVR9glOT',
#     'id': '2tZbAzQxbp2fvMbVR9glOT',
#     'images': [{'height': 640,
#       'url': 'https://i.scdn.co/image/f8b58c17cf15a8bb1520a059826fe2de0ed6be35',
#       'width': 640},
#      {'height': 320,
#       'url': 'https://i.scdn.co/image/ba4649722e4eede41389df9461a33331c1b4551e',
#       'width': 320},
#      {'height': 160,
#       'url': 'https://i.scdn.co/image/0c594f1e119119b2695d5240c952785227c684ea',
#       'width': 160}],
#     'name': 'Sleepy Times',
#     'popularity': 69,
#     'type': 'artist',
#     'uri': 'spotify:artist:2tZbAzQxbp2fvMbVR9glOT'},
#    {'external_urls': {'spotify': 'https://open.spotify.com/artist/3Op7D6tFVJCOHW6EAV0ck1'},
#     'followers': {'href': None, 'total': 111679},
#     'genres': ['indie pop'],
#     'href': 'https://api.spotify.com/v1/artists/3Op7D6tFVJCOHW6EAV0ck1',
#     'id': '3Op7D6tFVJCOHW6EAV0ck1',
#     'images': [{'height': 640,
#       'url': 'https://i.scdn.co/image/ab67616d0000b273ef32855c467398112c07e8d4',
#       'width': 640},
#      {'height': 300,
#       'url': 'https://i.scdn.co/image/ab67616d00001e02ef32855c467398112c07e8d4',
#       'width': 300},
#      {'height': 64,
#       'url': 'https://i.scdn.co/image/ab67616d00004851ef32855c467398112c07e8d4',
#       'width': 64}],
#     'name': 'Adventure Time',
#     'popularity': 62,
#     'type': 'artist',
#     'uri': 'spotify:artist:3Op7D6tFVJCOHW6EAV0ck1'},
#    {'external_urls': {'spotify': 'https://open.spotify.com/artist/1C0HVpji7xDIdGbnsdUwCt'},
#     'followers': {'href': None, 'total': 3650},
#     'genres': [],
#     'href': 'https://api.spotify.com/v1/artists/1C0HVpji7xDIdGbnsdUwCt',
#     'id': '1C0HVpji7xDIdGbnsdUwCt',
#     'images': [{'height': 1341,
#       'url': 'https://i.scdn.co/image/c248effd764b50f14a28e46d05c18e90ce2b79c5',
#       'width': 969},
#      {'height': 886,
#       'url': 'https://i.scdn.co/image/1f7d73ea38cbb4696a9e66deb29901edfd5fe722',
#       'width': 640},
#      {'height': 277,
#       'url': 'https://i.scdn.co/image/b455d5b30135cfe2870816e8ad176715760c5f21',
#       'width': 200},
#      {'height': 89,
#       'url': 'https://i.scdn.co/image/ebbbc993edfcb32af4fd194e0218f8e8ae3b6336',
#       'width': 64}],
#     'name': 'Timex Social Club',
#     'popularity': 36,
#     'type': 'artist',
#     'uri': 'spotify:artist:1C0HVpji7xDIdGbnsdUwCt'},
#    {'external_urls': {'spotify': 'https://open.spotify.com/artist/4rojTfP5nRkmYpdSbWQgV4'},
#     'followers': {'href': None, 'total': 19655},
#     'genres': ['video game music'],
#     'href': 'https://api.spotify.com/v1/artists/4rojTfP5nRkmYpdSbWQgV4',
#     'id': '4rojTfP5nRkmYpdSbWQgV4',
#     'images': [{'height': 640,
#       'url': 'https://i.scdn.co/image/acb07231849333272b2cd10d2b7ae61a2b96fdbc',
#       'width': 640},
#      {'height': 320,
#       'url': 'https://i.scdn.co/image/348cf873e5192bdeb5d207c2cdfb50da09c9b096',
#       'width': 320},
#      {'height': 160,
#       'url': 'https://i.scdn.co/image/bb3c60faa7e2bc8b5ee25daa8bb2080c7c4b9583',
#       'width': 160}],
#     'name': 'Death Stranding: Timefall',
#     'popularity': 67,
#     'type': 'artist',
#     'uri': 'spotify:artist:4rojTfP5nRkmYpdSbWQgV4'},
#    {'external_urls': {'spotify': 'https://open.spotify.com/artist/4FvojRROKYT9c7VJUkIy8i'},
#     'followers': {'href': None, 'total': 2332},
#     'genres': ['american metalcore'],
#     'href': 'https://api.spotify.com/v1/artists/4FvojRROKYT9c7VJUkIy8i',
#     'id': '4FvojRROKYT9c7VJUkIy8i',
#     'images': [{'height': 640,
#       'url': 'https://i.scdn.co/image/54a36b286d2530365067451433189fbda7a27676',
#       'width': 640},
#      {'height': 320,
#       'url': 'https://i.scdn.co/image/7206cb16a112c33e8f77b1df35527cac97733ee9',
#       'width': 320},
#      {'height': 160,
#       'url': 'https://i.scdn.co/image/c2a8e4c33087c47ded6aa510c0c931e741470e2c',
#       'width': 160}],
#     'name': 'TIMELESS',
#     'popularity': 33,
#     'type': 'artist',
#     'uri': 'spotify:artist:4FvojRROKYT9c7VJUkIy8i'},
#    {'external_urls': {'spotify': 'https://open.spotify.com/artist/4VM1KmVZIzzcsE0ZOLxCOB'},
#     'followers': {'href': None, 'total': 369},
#     'genres': ['focus trance', 'progressive breaks'],
#     'href': 'https://api.spotify.com/v1/artists/4VM1KmVZIzzcsE0ZOLxCOB',
#     'id': '4VM1KmVZIzzcsE0ZOLxCOB',
#     'images': [{'height': 640,
#       'url': 'https://i.scdn.co/image/ab67616d0000b27348ffb2402760deff20f647dd',
#       'width': 640},
#      {'height': 300,
#       'url': 'https://i.scdn.co/image/ab67616d00001e0248ffb2402760deff20f647dd',
#       'width': 300},
#      {'height': 64,
#       'url': 'https://i.scdn.co/image/ab67616d0000485148ffb2402760deff20f647dd',
#       'width': 64}],
#     'name': 'Timewave',
#     'popularity': 30,
#     'type': 'artist',
#     'uri': 'spotify:artist:4VM1KmVZIzzcsE0ZOLxCOB'},
#    {'external_urls': {'spotify': 'https://open.spotify.com/artist/4qJ4PtITSkwi3Z5311xSE2'},
#     'followers': {'href': None, 'total': 5717},
#     'genres': ['full on', 'progressive psytrance', 'psychedelic trance'],
#     'href': 'https://api.spotify.com/v1/artists/4qJ4PtITSkwi3Z5311xSE2',
#     'id': '4qJ4PtITSkwi3Z5311xSE2',
#     'images': [{'height': 640,
#       'url': 'https://i.scdn.co/image/553369c0f52995b436366f843e472e0a46c9ed70',
#       'width': 640},
#      {'height': 320,
#       'url': 'https://i.scdn.co/image/a8893d72366b808c02f28ef370a325cbdae7c0d1',
#       'width': 320},
#      {'height': 160,
#       'url': 'https://i.scdn.co/image/a80e0a2b9f2ccf0708666a4bb9fc38066c8ea9d7',
#       'width': 160}],
#     'name': 'Timelock',
#     'popularity': 42,
#     'type': 'artist',
#     'uri': 'spotify:artist:4qJ4PtITSkwi3Z5311xSE2'},
#    {'external_urls': {'spotify': 'https://open.spotify.com/artist/6M7RdR9ZP52h2mfNLmiHtU'},
#     'followers': {'href': None, 'total': 294978},
#     'genres': ['bass trap',
#      'brostep',
#      'edm',
#      'electro house',
#      'electronic trap'],
#     'href': 'https://api.spotify.com/v1/artists/6M7RdR9ZP52h2mfNLmiHtU',
#     'id': '6M7RdR9ZP52h2mfNLmiHtU',
#     'images': [{'height': 640,
#       'url': 'https://i.scdn.co/image/3e02c17888ab1efce84b78e4f677ec77cdde141d',
#       'width': 640},
#      {'height': 320,
#       'url': 'https://i.scdn.co/image/be2f4ee8c9e5b5edad2ab6475e6d1c32c6f9350a',
#       'width': 320},
#      {'height': 160,
#       'url': 'https://i.scdn.co/image/d6d9586db01cfc93eb2977b79c42f420f3626ce0',
#       'width': 160}],
#     'name': 'Good Times Ahead',
#     'popularity': 64,
#     'type': 'artist',
#     'uri': 'spotify:artist:6M7RdR9ZP52h2mfNLmiHtU'},
#    {'external_urls': {'spotify': 'https://open.spotify.com/artist/5M0HAqHXyOh3q7WQnvce8o'},
#     'followers': {'href': None, 'total': 55128},
#     'genres': ['chillwave',
#      'experimental pop',
#      'indie garage rock',
#      'indie pop',
#      'indietronica',
#      'neo-psychedelic',
#      'nu gaze'],
#     'href': 'https://api.spotify.com/v1/artists/5M0HAqHXyOh3q7WQnvce8o',
#     'id': '5M0HAqHXyOh3q7WQnvce8o',
#     'images': [{'height': 640,
#       'url': 'https://i.scdn.co/image/c08ef1a5036a34c8dffcc68c1e1e8219094d8fb2',
#       'width': 640},
#      {'height': 320,
#       'url': 'https://i.scdn.co/image/a3cbe669a3cee4c7cda95d6f5f86829be202abd9',
#       'width': 320},
#      {'height': 160,
#       'url': 'https://i.scdn.co/image/da6248316e8054b334f59c043aba057f9f35c8f4',
#       'width': 160}],
#     'name': 'Part Time',
#     'popularity': 53,
#     'type': 'artist',
#     'uri': 'spotify:artist:5M0HAqHXyOh3q7WQnvce8o'},
#    {'external_urls': {'spotify': 'https://open.spotify.com/artist/1LueZf9jSHrdmMJjZTLowI'},
#     'followers': {'href': None, 'total': 1724},
#     'genres': [],
#     'href': 'https://api.spotify.com/v1/artists/1LueZf9jSHrdmMJjZTLowI',
#     'id': '1LueZf9jSHrdmMJjZTLowI',
#     'images': [{'height': 640,
#       'url': 'https://i.scdn.co/image/ab67616d0000b273fa6a8c5071b9bd42056ed609',
#       'width': 640},
#      {'height': 300,
#       'url': 'https://i.scdn.co/image/ab67616d00001e02fa6a8c5071b9bd42056ed609',
#       'width': 300},
#      {'height': 64,
#       'url': 'https://i.scdn.co/image/ab67616d00004851fa6a8c5071b9bd42056ed609',
#       'width': 64}],
#     'name': 'Time Zone',
#     'popularity': 30,
#     'type': 'artist',
#     'uri': 'spotify:artist:1LueZf9jSHrdmMJjZTLowI'},
#    {'external_urls': {'spotify': 'https://open.spotify.com/artist/1LxC10tZiw6AYtRcemcvKr'},
#     'followers': {'href': None, 'total': 6383},
#     'genres': ['bboy', 'funky breaks', 'nu jazz'],
#     'href': 'https://api.spotify.com/v1/artists/1LxC10tZiw6AYtRcemcvKr',
#     'id': '1LxC10tZiw6AYtRcemcvKr',
#     'images': [{'height': 640,
#       'url': 'https://i.scdn.co/image/5358f11a0e123e22a8488b0a27ca7f37c039dfa5',
#       'width': 640},
#      {'height': 320,
#       'url': 'https://i.scdn.co/image/4aad554aef725a5d390aa436b982eab63bca0eb0',
#       'width': 320},
#      {'height': 160,
#       'url': 'https://i.scdn.co/image/1ba6036b6ad8424e1a88389f444117880c00981c',
#       'width': 160}],
#     'name': 'Timewarp Inc',
#     'popularity': 38,
#     'type': 'artist',
#     'uri': 'spotify:artist:1LxC10tZiw6AYtRcemcvKr'},
#    {'external_urls': {'spotify': 'https://open.spotify.com/artist/5GK2hLwkSIVQSaQMTAmLbk'},
#     'followers': {'href': None, 'total': 7270},
#     'genres': [],
#     'href': 'https://api.spotify.com/v1/artists/5GK2hLwkSIVQSaQMTAmLbk',
#     'id': '5GK2hLwkSIVQSaQMTAmLbk',
#     'images': [{'height': 640,
#       'url': 'https://i.scdn.co/image/f16b29bb5bca0ee284f09bf1b9c89e315195aece',
#       'width': 640},
#      {'height': 320,
#       'url': 'https://i.scdn.co/image/6d57fa4c5a46e68a085837c5b284562c21659542',
#       'width': 320},
#      {'height': 160,
#       'url': 'https://i.scdn.co/image/7ab6a6ca4c11b3fa6df0abed50cb77231488987a',
#       'width': 160}],
#     'name': 'Time For Three',
#     'popularity': 27,
#     'type': 'artist',
#     'uri': 'spotify:artist:5GK2hLwkSIVQSaQMTAmLbk'},
#    {'external_urls': {'spotify': 'https://open.spotify.com/artist/6113I12OVuEsTxsPUOnCTW'},
#     'followers': {'href': None, 'total': 7596},
#     'genres': ["punk 'n' roll", 'ska punk'],
#     'href': 'https://api.spotify.com/v1/artists/6113I12OVuEsTxsPUOnCTW',
#     'id': '6113I12OVuEsTxsPUOnCTW',
#     'images': [{'height': 640,
#       'url': 'https://i.scdn.co/image/e35f3f23474dc5c73fc191c88458ddf7527ba790',
#       'width': 640},
#      {'height': 320,
#       'url': 'https://i.scdn.co/image/f871ce9c4d654f2cde41798453ace95c6e576137',
#       'width': 320},
#      {'height': 160,
#       'url': 'https://i.scdn.co/image/9dd25c9ef3ff0ef719f7eabc0efb97b72692b2f3',
#       'width': 160}],
#     'name': 'Time Again',
#     'popularity': 28,
#     'type': 'artist',
#     'uri': 'spotify:artist:6113I12OVuEsTxsPUOnCTW'}],
#   'limit': 20,
#   'next': 'https://api.spotify.com/v1/search?query=Time&type=artist&offset=20&limit=20',
#   'offset': 0,
#   'previous': None,
#   'total': 4661}}
